# %% [markdown]
# # 抓取 PTT Soft_Job版的網頁原始碼(HTML)

# %%
import urllib.request as req

# %%
url = "https://www.ptt.cc/bbs/Soft_Job/index1589.html"

# %% [markdown]
# ## 建立一個 Request物件，附加 Request Headers的資訊

# %%
request = req.Request(url, headers={
    
    "User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.125 Safari/537.36"
})

# %%
with req.urlopen(request) as response:
    data = response.read().decode("utf-8")
print(data)
# Out:
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>看板 Soft_Job 文章列表 - 批踢踢實業坊</title>
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# 	</head>
#     <body>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Soft_Job/index.html"><span class="board-label">看板 </span>Soft_Job</a>
# ...

# %% [markdown]
# ## 解析原始碼，取得每篇文章的標題

# %%
import bs4

# %%
# root = bs4.BeautifulSoup(data, "html.parser")
# print(root.title)
# Out:
# <title>看板 Soft_Job 文章列表 - 批踢踢實業坊</title>

# %%
#尋找 class="title"的 div標籤
titles = root.find("div", class_ = "title") 
print(titles.a.string)
# Out:
# Re: [請益] 大家爬蟲都爬什麼好玩？

# %%
#尋找 class="title"的 div標籤
titles = root.find_all("div", class_ = "title")

for title in titles:
    if title.a != None: # 如果標題包含 a標籤(沒有被刪除)
        print(title.a.string)
# Out:
# Re: [請益] 大家爬蟲都爬什麼好玩？
# Re: [請益] 大家爬蟲都爬什麼好玩？
# [請益] 寫程式是不是跟個性有關？
# Re: [請益] 大學休學去全心工作
# Re: [請益] 大學休學去全心工作
# [請益] 職訓跟自學前端問題
# [徵才] aifian 誠徵資深前端工程師(年薪90萬起)
# [請益] 金融業程式有bug怎辦？
# [請益] 碩班技能點要點AI 還是WEB
# [徵才] 豆沙科技徵求junior網站前端工程師
# [請益] 陷入人生的煩惱了 請問
# [討論] 選課疑問以及方向詢問
# Re: [請益] 金融業程式有bug怎辦？
# [請益] 新鮮人offer請益
# [心得] 笑談軟體測試的幾個階段（六）歷史代碼
# [討論] 手機遊戲刪掉紀錄會繼續存在？
# [請益] 該不該去博奕業
# Re: [請益] 大學休學去全心工作
# [心得][英文] 如何命名「檢查」功能２
# [請益] 轉職Offer請益
